# %% [markdown]
# <a href="https://colab.research.google.com/github/saikala0109/AI-12-Days-Bootcamp/blob/main/Day10_10A_MultiAgent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q "numpy<2.0"
# !pip install -q --upgrade crewai litellm google-generativeai google-genai

# %%
import os, getpass

os.environ["GEMINI_API_KEY"] = getpass.getpass("Enter Gemini API Key: ")

print("API key set")
# Out:
# Enter Gemini API Key: ··········
# API key set

# %%
from crewai import Agent, Task, Crew, Process

print("CrewAI imported successfully")
# Out:
# 05:17:26 - LiteLLM:WARNING: common_utils.py:979 - litellm: could not pre-load bedrock-runtime response stream shape — Bedrock event-stream decoding will be unavailable. Error: No module named 'botocore'
# WARNING:LiteLLM:litellm: could not pre-load bedrock-runtime response stream shape — Bedrock event-stream decoding will be unavailable. Error: No module named 'botocore'
# 05:17:26 - LiteLLM:WARNING: common_utils.py:24 - litellm: could not pre-load sagemaker-runtime response stream shape — SageMaker event-stream decoding will be unavailable. Error: No module named 'botocore'
# WARNING:LiteLLM:litellm: could not pre-load sagemaker-runtime response stream shape — SageMaker event-stream decoding will be unavailable. Error: No module named 'botocore'
# CrewAI imported successfully

# %%
llm = "gemini/gemini-2.5-flash"

print(llm)
# Out:
# gemini/gemini-2.5-flash

# %%
researcher = Agent(
    role="Placement Researcher",
    goal="Compile concise, factual placement-prep notes for B.Tech students",
    backstory="You are a research analyst who prepares short factual placement briefs in bullet form.",
    llm=llm,
    verbose=True,
    allow_delegation=False,
)

print("Researcher agent created")
# Out:
# Researcher agent created

# %%
writer = Agent(
    role="Placement Brief Writer",
    goal="Convert research notes into a clean 1-page placement brief in markdown",
    backstory="You write clear student-friendly placement briefs with headings and actionable takeaways.",
    llm=llm,
    verbose=True,
    allow_delegation=False,
)

print("Writer agent created")
# Out:
# Writer agent created

# %%
research_task = Task(
    description=(
        "Research TCS Digital placement preparation for B.Tech students. "
        "Include hiring process, technical stack, eligibility, recent hiring trends, "
        "and preparation tips. Give 3-5 bullets per section."
    ),
    agent=researcher,
    expected_output=(
        "Markdown bullet list with 5 sections: Hiring Process, Technical Stack, "
        "Eligibility, Recent Hiring Trends, Prep Tips."
    ),
)

print("Research task created")
# Out:
# Research task created

# %%
write_task = Task(
    description=(
        "Using the research notes, produce a 1-page placement brief for B.Tech students. "
        "Use markdown format. Include a 3-line opening hook, 5 clear sections, "
        "and a 3-line closing call-to-action."
    ),
    agent=writer,
    expected_output='1-page markdown brief titled "TCS Digital — Placement Prep Brief".',
)

print("Writer task created")
# Out:
# Writer task created

# %%
crew = Crew(
    agents=[researcher, writer],
    tasks=[research_task, write_task],
    process=Process.sequential,
    verbose=True,
)

print("Crew created successfully")
# Out:
# Crew created successfully

# %%
result = await crew.kickoff_async()

print("\n\n=== FINAL OUTPUT ===\n")
print(result)
# Out:
# ╭─────────────────────────────────────────── 🚀 Crew Execution Started ───────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: 0ed477ca-538c-4588-86dd-0dd5a633b351                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Started                                                                                                   │
# │  Name: Research TCS Digital placement preparation for B.Tech students. Include hiring process, technical        │
# │  stack, eligibility, recent hiring trends, and preparation tips. Give 3-5 bullets per section.                  │
# │  ID: 5af274f6-1ed0-47f6-86eb-8a21724f888d                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Placement Researcher                                                                                    │
# │                                                                                                                 │
# │  Task: Research TCS Digital placement preparation for B.Tech students. Include hiring process, technical        │
# │  stack, eligibility, recent hiring trends, and preparation tips. Give 3-5 bullets per section.                  │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# [Finalize] todos_count=0, todos_with_results=0
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Placement Researcher                                                                                    │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  Here's a placement brief for TCS Digital preparation for B.Tech students:                                      │
# │                                                                                                                 │
# │  ### Hiring Process                                                                                             │
# │  *   **Online Assessment (TCS NQT or Digital-specific Test):** Typically includes quantitative aptitude,        │
# │  logical reasoning, verbal ability, and a foundational coding section. TCS Digital usually requires a higher    │
# │  NQT score or features more advanced problems.                                                                  │
# │  *   **Advanced Coding Round:** This is a crucial differentiator for Digital. It involves solving 1-2 complex   │
# │  programming problems, focusing heavily on data structures, algorithms, and optimized solutions.                │
# │  *   **Technical Interview (TI):** In-depth discussion on projects, programming concepts (OOPs), DSA, core CS   │
# │  subjects (OS, DBMS, CN), preferred technologies, and problem-solving approach.                                 │
# │  *   **Managerial Interview (MI):** Focuses on leadership potential, problem-solving skills, career             │
# │  aspirations, teamwork, and situational judgment. Sometimes combined with TI or skipped.                        │
# │  *   **HR Interview (HR):** Standard HR questions about background, communication skills, willingness to        │
# │  relocate, compensation expectations, and company fit.                                                          │
# │                                                                                                                 │
# │  ### Technical Stack                                                                                            │
# │  *   **Core Programming Languages:** Strong proficiency in Java, Python, C++, and/or JavaScript, coupled with   │
# │  excellent Data Structures and Algorithms (DSA) skills.                                                         │
# │  *   **Web Technologies:** Experience with modern web development frameworks like Spring Boot (Java), Node.js   │
# │  (JavaScript), React, Angular, or Vue.js for full-stack roles.                                                  │
# │  *   **Cloud Computing:** Familiarity with major cloud platforms such as AWS, Microsoft Azure, or Google Cloud  │
# │  Platform (GCP) and their services.                                                                             │
# │  *   **Databases:** Understanding of both SQL (e.g., MySQL, PostgreSQL) and NoSQL databases (e.g., MongoDB,     │
# │  Cassandra).                                                                                                    │
# │  *   **Emerging Technologies:** Basic understanding or project experience in areas like Machine Learning,       │
# │  Artificial Intelligence, IoT, or Blockchain, depending on the role.                                            │
# │                                                                                                                 │
# │  ### Eligibility                                                                                                │
# │  *   **Academic Qualification:** B.E./B.Tech degree in Computer Science, Information Technology, Electronics &  │
# │  Communication, Electrical Engineering, or related fields.                                                      │
# │  *   **Academic Aggregate:** A consistent academic record, typically with a minimum of 60% or 7 CGPA            │
# │  throughout 10th, 12th, and Graduation.                                                                         │
# │  *   **Backlogs:** No active backlogs at the time of applying and joining.                                      │
# │  *   **Gap in Education:** A maximum of 1 year gap in education is generally permissible.                       │
# │  *   **Age Limit:** Candidates typically need to be between 18 and 28 years of age.                             │
# │                                                                                                                 │
# │  ### Recent Hiring Trends                                                                                       │
# │  *   **Advanced DSA & Problem Solving:** Increased emphasis on candidates' ability to solve complex             │
# │  algorithmic problems efficiently, often tested through multiple advanced coding rounds.                        │
# │  *   **Cloud Skills:** Significant demand for candidates with hands-on experience or certifications in cloud    │
# │  platforms (AWS, Azure, GCP) due to accelerated digital transformation initiatives.                             │
# │  *   **Project-Based Evaluation:** Strong preference for candidates who can demonstrate practical application   │
# │  of their skills through robust personal or academic projects, especially those leveraging cutting-edge         │
# │  technologies.                                                                                                  │
# │  *   **Full-Stack Development:** Growing focus on hiring individuals capable of working across both front-end   │
# │  and back-end development, showcasing versatility.                                                              │
# │  *   **Communication & Critical Thinking:** Beyond technical prowess, interviewers are increasingly assessing   │
# │  candidates' ability to articulate solutions, ask clarifying questions, and think critically under pressure.    │
# │                                                                                                                 │
# │  ### Prep Tips                                                                                                  │
# │  *   **Master Data Structures & Algorithms:** Practice regularly on platforms like LeetCode (target medium to   │
# │  hard problems), HackerRank, and GeeksforGeeks. This is paramount for the advanced coding rounds.               │
# │  *   **Build Strong Projects:** Develop 2-3 significant, well-documented projects. Focus on utilizing modern    │
# │  frameworks, cloud services, and demonstrating problem-solving abilities. Be ready to explain your              │
# │  architecture, challenges, and learning.                                                                        │
# │  *   **Strengthen Core CS Fundamentals:** Thoroughly revise Operating Systems, Database Management Systems      │
# │  (DBMS), Object-Oriented Programming (OOPs) concepts, and Computer Networks. These are frequently tested in     │
# │  technical interviews.                                                                                          │
# │  *   **Learn a Cloud Platform:** Get hands-on experience with at least one major cloud provider (AWS, Azure,    │
# │  or GCP). Understand basic services (compute, storage, networking, databases) and consider pursuing an          │
# │  entry-level certification.                                                                                     │
# │  *   **Practice Mock Interviews:** Engage in mock technical and HR interviews to refine your communication      │
# │  skills, practice explaining your thought process for coding problems, and prepare answers for common           │
# │  behavioral questions.                                                                                          │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭────────────────────────────────────────────── 📋 Task Completion ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: Research TCS Digital placement preparation for B.Tech students. Include hiring process, technical        │
# │  stack, eligibility, recent hiring trends, and preparation tips. Give 3-5 bullets per section.                  │
# │  Agent: Placement Researcher                                                                                    │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Started                                                                                                   │
# │  Name: Using the research notes, produce a 1-page placement brief for B.Tech students. Use markdown format.     │
# │  Include a 3-line opening hook, 5 clear sections, and a 3-line closing call-to-action.                          │
# │  ID: 10615363-dc33-400e-bfe5-77263a7f7ea6                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Placement Brief Writer                                                                                  │
# │                                                                                                                 │
# │  Task: Using the research notes, produce a 1-page placement brief for B.Tech students. Use markdown format.     │
# │  Include a 3-line opening hook, 5 clear sections, and a 3-line closing call-to-action.                          │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# [Finalize] todos_count=0, todos_with_results=0
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Placement Brief Writer                                                                                  │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  # TCS Digital — Placement Prep Brief                                                                           │
# │                                                                                                                 │
# │  Dreaming of a high-impact tech career? TCS Digital offers coveted roles for innovators ready to shape the      │
# │  future.                                                                                                        │
# │  This brief is your essential guide to navigating the TCS Digital hiring process, equipping you with the        │
# │  knowledge to stand out.                                                                                        │
# │  Get ready to unlock your potential and secure your dream placement!                                            │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ### 1. The Hiring Process — Your Path to Digital                                                               │
# │                                                                                                                 │
# │  TCS Digital's selection is rigorous, designed to identify top talent. Be prepared for:                         │
# │                                                                                                                 │
# │  *   **Online Assessment:** This usually involves a higher-difficulty TCS NQT or a Digital-specific test.       │
# │  Expect sections on quantitative aptitude, logical reasoning, verbal ability, and foundational coding.          │
# │  *   **Advanced Coding Round:** A critical differentiator! You'll solve 1-2 complex programming problems, with  │
# │  a heavy focus on efficient Data Structures and Algorithms (DSA).                                               │
# │  *   **Technical Interview (TI):** Deep dive into your projects, core programming concepts (OOPs), DSA, and     │
# │  Computer Science fundamentals (OS, DBMS, CN). Be ready to discuss your preferred technologies and              │
# │  problem-solving approach.                                                                                      │
# │  *   **Managerial Interview (MI):** Assesses leadership potential, problem-solving skills, career aspirations,  │
# │  teamwork, and situational judgment. This might sometimes be combined with the TI.                              │
# │  *   **HR Interview (HR):** Standard questions about your background, communication skills, willingness to      │
# │  relocate, compensation expectations, and cultural fit.                                                         │
# │                                                                                                                 │
# │  ### 2. Technical Stack — Key Skills to Master                                                                  │
# │                                                                                                                 │
# │  To excel in TCS Digital, focus on building proficiency in these areas:                                         │
# │                                                                                                                 │
# │  *   **Core Programming & DSA:** Strong command of Java, Python, C++, and/or JavaScript, coupled with           │
# │  excellent Data Structures and Algorithms skills.                                                               │
# │  *   **Web Technologies:** Experience with modern web frameworks such as Spring Boot (Java), Node.js            │
# │  (JavaScript), React, Angular, or Vue.js for full-stack roles.                                                  │
# │  *   **Cloud Computing:** Familiarity with major cloud platforms like AWS, Microsoft Azure, or Google Cloud     │
# │  Platform (GCP) and their core services.                                                                        │
# │  *   **Databases:** Understanding of both SQL (e.g., MySQL, PostgreSQL) and NoSQL databases (e.g., MongoDB,     │
# │  Cassandra).                                                                                                    │
# │  *   **Emerging Technologies:** Basic understanding or project experience in areas such as Machine Learning,    │
# │  Artificial Intelligence, IoT, or Blockchain, relevant to specific roles.                                       │
# │                                                                                                                 │
# │  ### 3. Eligibility Criteria — Are You Ready?                                                                   │
# │                                                                                                                 │
# │  Ensure you meet the foundational requirements for TCS Digital:                                                 │
# │                                                                                                                 │
# │  *   **Academic Qualification:** A B.E./B.Tech degree in Computer Science, Information Technology, Electronics  │
# │  & Communication, Electrical Engineering, or related fields.                                                    │
# │  *   **Academic Aggregate:** A consistent academic record, typically with a minimum of 60% or 7 CGPA            │
# │  throughout 10th, 12th, and Graduation.                                                                         │
# │  *   **Backlogs:** No active backlogs at the time of applying and joining.                                      │
# │  *   **Gap in Education:** A maximum of 1 year gap in education is generally permissible.                       │
# │  *   **Age Limit:** Candidates typically need to be between 18 and 28 years of age.                             │
# │                                                                                                                 │
# │  ### 4. Recent Hiring Trends — What TCS Digital Looks For                                                       │
# │                                                                                                                 │
# │  TCS Digital's hiring reflects the evolving tech landscape. Focus on these areas to align with their            │
# │  expectations:                                                                                                  │
# │                                                                                                                 │
# │  *   **Advanced DSA & Problem Solving:** Increased emphasis on efficiently solving complex algorithmic          │
# │  problems, often tested through multiple advanced coding rounds.                                                │
# │  *   **Cloud Skills:** Significant demand for candidates with hands-on experience or certifications in cloud    │
# │  platforms (AWS, Azure, GCP) due to accelerated digital transformation.                                         │
# │  *   **Project-Based Evaluation:** Strong preference for candidates who demonstrate practical application of    │
# │  skills through robust projects, especially those leveraging cutting-edge technologies.                         │
# │  *   **Full-Stack Development:** Growing focus on individuals capable of working across both front-end and      │
# │  back-end development, showcasing versatility.                                                                  │
# │  *   **Communication & Critical Thinking:** Beyond technical prowess, interviewers assess your ability to       │
# │  articulate solutions, ask clarifying questions, and think critically under pressure.                           │
# │                                                                                                                 │
# │  ### 5. Preparation Tips — Your Action Plan                                                                     │
# │                                                                                                                 │
# │  Your dedicated effort in these areas will significantly boost your chances:                                    │
# │                                                                                                                 │
# │  *   **Master Data Structures & Algorithms:** Practice regularly on platforms like LeetCode (target medium to   │
# │  hard problems), HackerRank, and GeeksforGeeks. This is paramount for the advanced coding rounds.               │
# │  *   **Build Strong Projects:** Develop 2-3 significant, well-documented projects. Focus on utilizing modern    │
# │  frameworks, cloud services, and demonstrating problem-solving abilities. Be ready to explain your              │
# │  architecture, challenges, and learnings.                                                                       │
# │  *   **Strengthen Core CS Fundamentals:** Thoroughly revise Operating Systems, Database Management Systems      │
# │  (DBMS), Object-Oriented Programming (OOPs) concepts, and Computer Networks. These are frequently tested in     │
# │  technical interviews.                                                                                          │
# │  *   **Learn a Cloud Platform:** Get hands-on experience with at least one major cloud provider (AWS, Azure,    │
# │  or GCP). Understand basic services (compute, storage, networking, databases) and consider pursuing an          │
# │  entry-level certification.                                                                                     │
# │  *   **Practice Mock Interviews:** Engage in mock technical and HR interviews to refine your communication      │
# │  skills, practice explaining your thought process for coding problems, and prepare answers for common           │
# │  behavioral questions.                                                                                          │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  TCS Digital offers an incredible platform to kickstart your career with cutting-edge technology.               │
# │  Start preparing today with focus and consistency, leveraging these insights to your advantage.                 │
# │  Your journey to a dynamic and rewarding career begins now – seize the opportunity!                             │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭────────────────────────────────────────────── 📋 Task Completion ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: Using the research notes, produce a 1-page placement brief for B.Tech students. Use markdown format.     │
# │  Include a 3-line opening hook, 5 clear sections, and a 3-line closing call-to-action.                          │
# │  Agent: Placement Brief Writer                                                                                  │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# === FINAL OUTPUT ===
#
# # TCS Digital — Placement Prep Brief
#
# Dreaming of a high-impact tech career? TCS Digital offers coveted roles for innovators ready to shape the future.
# This brief is your essential guide to navigating the TCS Digital hiring process, equipping you with the knowledge to stand out.
# Get ready to unlock your potential and secure your dream placement!
#
# ---
#
# ### 1. The Hiring Process — Your Path to Digital
#
# TCS Digital's selection is rigorous, designed to identify top talent. Be prepared for:
#
# *   **Online Assessment:** This usually involves a higher-difficulty TCS NQT or a Digital-specific test. Expect sections on quantitative aptitude, logical reasoning, verbal ability, and foundational coding.
# *   **Advanced Coding Round:** A critical differentiator! You'll solve 1-2 complex programming problems, with a heavy focus on efficient Data Structures and Algorithms (DSA).
# *   **Technical Interview (TI):** Deep dive into your projects, core programming concepts (OOPs), DSA, and Computer Science fundamentals (OS, DBMS, CN). Be ready to discuss your preferred technologies and problem-solving approach.
# *   **Managerial Interview (MI):** Assesses leadership potential, problem-solving skills, career aspirations, teamwork, and situational judgment. This might sometimes be combined with the TI.
# *   **HR Interview (HR):** Standard questions about your background, communication skills, willingness to relocate, compensation expectations, and cultural fit.
#
# ### 2. Technical Stack — Key Skills to Master
#
# To excel in TCS Digital, focus on building proficiency in these areas:
#
# *   **Core Programming & DSA:** Strong command of Java, Python, C++, and/or JavaScript, coupled with excellent Data Structures and Algorithms skills.
# *   **Web Technologies:** Experience with modern web frameworks such as Spring Boot (Java), Node.js (JavaScript), React, Angular, or Vue.js for full-stack roles.
# *   **Cloud Computing:** Familiarity with major cloud platforms like AWS, Microsoft Azure, or Google Cloud Platform (GCP) and their core services.
# *   **Databases:** Understanding of both SQL (e.g., MySQL, PostgreSQL) and NoSQL databases (e.g., MongoDB, Cassandra).
# *   **Emerging Technologies:** Basic understanding or project experience in areas such as Machine Learning, Artificial Intelligence, IoT, or Blockchain, relevant to specific roles.
#
# ### 3. Eligibility Criteria — Are You Ready?
#
# Ensure you meet the foundational requirements for TCS Digital:
#
# *   **Academic Qualification:** A B.E./B.Tech degree in Computer Science, Information Technology, Electronics & Communication, Electrical Engineering, or related fields.
# *   **Academic Aggregate:** A consistent academic record, typically with a minimum of 60% or 7 CGPA throughout 10th, 12th, and Graduation.
# *   **Backlogs:** No active backlogs at the time of applying and joining.
# *   **Gap in Education:** A maximum of 1 year gap in education is generally permissible.
# *   **Age Limit:** Candidates typically need to be between 18 and 28 years of age.
#
# ### 4. Recent Hiring Trends — What TCS Digital Looks For
#
# TCS Digital's hiring reflects the evolving tech landscape. Focus on these areas to align with their expectations:
#
# *   **Advanced DSA & Problem Solving:** Increased emphasis on efficiently solving complex algorithmic problems, often tested through multiple advanced coding rounds.
# *   **Cloud Skills:** Significant demand for candidates with hands-on experience or certifications in cloud platforms (AWS, Azure, GCP) due to accelerated digital transformation.
# *   **Project-Based Evaluation:** Strong preference for candidates who demonstrate practical application of skills through robust projects, especially those leveraging cutting-edge technologies.
# *   **Full-Stack Development:** Growing focus on individuals capable of working across both front-end and back-end development, showcasing versatility.
# *   **Communication & Critical Thinking:** Beyond technical prowess, interviewers assess your ability to articulate solutions, ask clarifying questions, and think critically under pressure.
#
# ### 5. Preparation Tips — Your Action Plan
#
# Your dedicated effort in these areas will significantly boost your chances:
#
# *   **Master Data Structures & Algorithms:** Practice regularly on platforms like LeetCode (target medium to hard problems), HackerRank, and GeeksforGeeks. This is paramount for the advanced coding rounds.
# *   **Build Strong Projects:** Develop 2-3 significant, well-documented projects. Focus on utilizing modern frameworks, cloud services, and demonstrating problem-solving abilities. Be ready to explain your architecture, challenges, and learnings.
# *   **Strengthen Core CS Fundamentals:** Thoroughly revise Operating Systems, Database Management Systems (DBMS), Object-Oriented Programming (OOPs) concepts, and Computer Networks. These are frequently tested in technical interviews.
# *   **Learn a Cloud Platform:** Get hands-on experience with at least one major cloud provider (AWS, Azure, or GCP). Understand basic services (compute, storage, networking, databases) and consider pursuing an entry-level certification.
# *   **Practice Mock Interviews:** Engage in mock technical and HR interviews to refine your communication skills, practice explaining your thought process for coding problems, and prepare answers for common behavioral questions.
#
# ---
#
# TCS Digital offers an incredible platform to kickstart your career with cutting-edge technology.
# Start preparing today with focus and consistency, leveraging these insights to your advantage.
# Your journey to a dynamic and rewarding career begins now – seize the opportunity!

# %%
import pathlib

pathlib.Path("day10_lab10a_transcript.txt").write_text(str(result))

print("Saved: day10_lab10a_transcript.txt")
print("Characters:", len(str(result)))
# Out:
# Saved: day10_lab10a_transcript.txt
# Characters: 5615

# %%
try:
    for i, output in enumerate(result.tasks_output):
        print(f"\n=== Task {i+1} Output ===")
        print(str(output)[:800])
except Exception:
    print("Task outputs not available in this CrewAI version.")
    print("Final result saved successfully.")
# Out:
# === Task 1 Output ===
# Here's a placement brief for TCS Digital preparation for B.Tech students:
#
# ### Hiring Process
# *   **Online Assessment (TCS NQT or Digital-specific Test):** Typically includes quantitative aptitude, logical reasoning, verbal ability, and a foundational coding section. TCS Digital usually requires a higher NQT score or features more advanced problems.
# *   **Advanced Coding Round:** This is a crucial differentiator for Digital. It involves solving 1-2 complex programming problems, focusing heavily on data structures, algorithms, and optimized solutions.
# *   **Technical Interview (TI):** In-depth discussion on projects, programming concepts (OOPs), DSA, core CS subjects (OS, DBMS, CN), preferred technologies, and problem-solving approach.
# *   **Managerial Interview (MI):** Focuses on leadershi
#
# === Task 2 Output ===
# # TCS Digital — Placement Prep Brief
#
# Dreaming of a high-impact tech career? TCS Digital offers coveted roles for innovators ready to shape the future.
# This brief is your essential guide to navigating the TCS Digital hiring process, equipping you with the knowledge to stand out.
# Get ready to unlock your potential and secure your dream placement!
#
# ---
#
# ### 1. The Hiring Process — Your Path to Digital
#
# TCS Digital's selection is rigorous, designed to identify top talent. Be prepared for:
#
# *   **Online Assessment:** This usually involves a higher-difficulty TCS NQT or a Digital-specific test. Expect sections on quantitative aptitude, logical reasoning, verbal ability, and foundational coding.
# *   **Advanced Coding Round:** A critical differentiator! You'll solve 1-2 complex programming proble

# %%
markdown_content = str(result)

with open("tcs_digital_brief.md", "w", encoding="utf-8") as f:
    f.write(markdown_content)

print("Markdown file created successfully: tcs_digital_brief.md")
# Out:
# Markdown file created successfully: tcs_digital_brief.md

# %%
from google.colab import files

files.download("tcs_digital_brief.md")

# %%
with open("tcs_digital_brief.md", "r", encoding="utf-8") as f:
    print(f.read()[:2000])
# Out:
# # TCS Digital — Placement Prep Brief
#
# Dreaming of a high-impact tech career? TCS Digital offers coveted roles for innovators ready to shape the future.
# This brief is your essential guide to navigating the TCS Digital hiring process, equipping you with the knowledge to stand out.
# Get ready to unlock your potential and secure your dream placement!
#
# ---
#
# ### 1. The Hiring Process — Your Path to Digital
#
# TCS Digital's selection is rigorous, designed to identify top talent. Be prepared for:
#
# *   **Online Assessment:** This usually involves a higher-difficulty TCS NQT or a Digital-specific test. Expect sections on quantitative aptitude, logical reasoning, verbal ability, and foundational coding.
# *   **Advanced Coding Round:** A critical differentiator! You'll solve 1-2 complex programming problems, with a heavy focus on efficient Data Structures and Algorithms (DSA).
# *   **Technical Interview (TI):** Deep dive into your projects, core programming concepts (OOPs), DSA, and Computer Science fundamentals (OS, DBMS, CN). Be ready to discuss your preferred technologies and problem-solving approach.
# *   **Managerial Interview (MI):** Assesses leadership potential, problem-solving skills, career aspirations, teamwork, and situational judgment. This might sometimes be combined with the TI.
# *   **HR Interview (HR):** Standard questions about your background, communication skills, willingness to relocate, compensation expectations, and cultural fit.
#
# ### 2. Technical Stack — Key Skills to Master
#
# To excel in TCS Digital, focus on building proficiency in these areas:
#
# *   **Core Programming & DSA:** Strong command of Java, Python, C++, and/or JavaScript, coupled with excellent Data Structures and Algorithms skills.
# *   **Web Technologies:** Experience with modern web frameworks such as Spring Boot (Java), Node.js (JavaScript), React, Angular, or Vue.js for full-stack roles.
# *   **Cloud Computing:** Familiarity with major cloud platforms like AWS, Microsoft Azure, or Google Cloud Pla
